# %% [markdown]
# <a href="https://colab.research.google.com/github/Jamesvh12346/Jamesvh12346.github.io/blob/main/pmtrackerscraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tabula-py

# %%
import tabula

# %%
file1 = "https://docs.cdn.yougov.com/yx9dysl1ym/YG%20trackers%20-%20Best%20Prime%20Minister_W.pdf"

# %%
table = tabula.read_pdf(file1,pages=1)

# %%
table[0]
# Out:
#              Unnamed: 0         Unnamed: 1  ... Refused Johnson\rLead
# 0                   NaN                NaN  ...       %             %
# 1   Start of\rFieldwork  End of\rFieldwork  ...     NaN           NaN
# 2                  2021                NaN  ...     NaN           NaN
# 3            19/12/2021         20/12/2021  ...       5           -12
# 4            14/12/2021         15/12/2021  ...       4           -10
# 5            01/12/2021         02/12/2021  ...       4            -4
# 6            24/11/2021         25/11/2021  ...       3            -1
# 7            17/11/2021         18/11/2021  ...       5            -2
# 8            10/11/2021         11/11/2021  ...       3            -2
# 9            12/10/2021         13/10/2021  ...       3             6
# 10           15/09/2021         16/09/2021  ...       5             5
# 11           02/09/2021         03/09/2021  ...       5             5
# ...

# %%
tabula.convert_into("https://docs.cdn.yougov.com/yx9dysl1ym/YG%20trackers%20-%20Best%20Prime%20Minister_W.pdf", "pmtracker.csv")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
